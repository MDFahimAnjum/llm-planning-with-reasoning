# %% [markdown]
# e2e rerank check mode

# %%
from utils.results import parse_results, plot_accuracy, plot_partial_matching, plot_matching

result_fnames ={
    "r1": "results/stable-code-3b_DeepSeek-R1-Distill-Qwen-1.5B_reason_spider_rerank_check_e2e_t2_20250218_011727.txt",
    '13b': "results/stable-code-3b_CodeLlama-13b-Instruct-hf_base_spider_rerank_check_e2e_t2_20250219_155402.txt",
    '7b': 'results/stable-code-3b_CodeLlama-7b-Instruct-hf_base_spider_rerank_check_e2e_t2_20250219_145954.txt',
    "greedy": "results/stable-code-3b_TinyLlama-1.1B-Chat-v1.0_spider_greedy_pro_e2e.txt",
    'stablecode': "results/stable-code-3b_stable-code-3b_base_spider_rerank_check_e2e_t2_20250218_180639.txt",
    'deepseekcoder': "results/stable-code-3b_deepseek-coder-1.3b-instruct_base_spider_rerank_check_e2e_t2_20250219_033724.txt",
#    "r2": "results\stable-code-3b_DeepSeek-R1-Distill-Qwen-1.5B_reason_spider_prune_pro_e2e_V2.txt",
#    't1': 'results/stable-code-3b_TinyLlama-1.1B-Chat-v1.0_base_spider_rerank_pro_e2e_t2.txt',
    "tinyllama": "results/stable-code-3b_TinyLlama-1.1B-Chat-v1.0_base_spider_rerank_check_e2e_t2_20250218_222930.txt"
}

groups = ['Distill R1-1.5B',
          'CodeLlama-13B',
          'CodeLlama-7B',
          'Baseline (Greedy)',
          'Stable Code-3B',
          'Deepseek Coder-1.3B',
          #'V2',
          #'t1',
          'TinyLlama-1.1B']

results = parse_results(result_fnames)
plot_accuracy(results=results, groups=groups)
plot_partial_matching(results=results,groups=groups)
plot_matching(results=results,groups=groups,subClass_indx=-1)
# Out:
# ========Execution Accuracy=============
#
#
# | Group | Easy | Medium | Hard | ExtraHard | All |
# |------|-------|-----|----------|----|
# | Distill R1-1.5B | 85.00 | 70.00 | 52.00 | 26.00 | 58.30 |
# | CodeLlama-13B | 85.00 | 74.00 | 52.00 | 22.00 | 58.30 |
# | CodeLlama-7B | 83.00 | 70.00 | 54.00 | 26.00 | 58.30 |
# | Baseline (Greedy) | 83.00 | 73.00 | 51.00 | 24.00 | 57.80 |
# | Stable Code-3B | 80.00 | 72.00 | 55.00 | 22.00 | 57.30 |
# | Deepseek Coder-1.3B | 83.00 | 67.00 | 49.00 | 25.00 | 56.00 |
# | TinyLlama-1.1B | 83.00 | 69.00 | 51.00 | 23.00 | 56.50 |
# ========Exact Matching Accuracy=============
#
#
# | Group | Easy | Medium | Hard | ExtraHard | All |
# |------|-------|-----|----------|----|
# | Distill R1-1.5B | 67.00 | 31.00 | 21.00 | 2.00 | 30.20 |
# | CodeLlama-13B | 73.00 | 32.00 | 30.00 | 3.00 | 34.50 |
# | CodeLlama-7B | 64.00 | 30.00 | 25.00 | 2.00 | 30.20 |
# | Baseline (Greedy) | 73.00 | 32.00 | 26.00 | 4.00 | 33.80 |
# ...

# %% [markdown]
# e2e rerank naive mode

# %%
result_fnames ={
    "r1": "results/stable-code-3b_DeepSeek-R1-Distill-Qwen-1.5B_reason_spider_rerank_base_e2e_t2_20250218_092532.txt",
    '13b': "results/stable-code-3b_CodeLlama-13b-Instruct-hf_base_spider_rerank_base_e2e_t2_20250219_151152.txt",
    '7b': 'results/stable-code-3b_CodeLlama-7b-Instruct-hf_base_spider_rerank_base_e2e_t2_20250219_144708.txt',
#    "greedy": "results/stable-code-3b_TinyLlama-1.1B-Chat-v1.0_spider_greedy_pro_e2e.txt",
    'stablecode': "results/stable-code-3b_stable-code-3b_base_spider_rerank_base_e2e_t2_20250218_162418.txt",
    'deepseekcoder': "results/stable-code-3b_deepseek-coder-1.3b-instruct_base_spider_rerank_base_e2e_t2_20250219_021719.txt",
#    "r2": "results\stable-code-3b_DeepSeek-R1-Distill-Qwen-1.5B_reason_spider_prune_pro_e2e_V2.txt",
#    't1': 'results/stable-code-3b_TinyLlama-1.1B-Chat-v1.0_base_spider_rerank_pro_e2e_t2.txt',
    "tinyllama": "results/stable-code-3b_TinyLlama-1.1B-Chat-v1.0_base_spider_rerank_base_e2e_t2_20250218_205734.txt"
}

groups = ['Distill R1-1.5B',
          'CodeLlama-13B',
          'CodeLlama-7B',
         # 'Baseline (Greedy)',
          'Stable Code-3B',
          'Deepseek Coder-1.3B',
          #'V2',
          #'t1',
          'TinyLlama-1.1B']

results = parse_results(result_fnames)
plot_accuracy(results=results, groups=groups)
plot_partial_matching(results=results,groups=groups)
plot_matching(results=results,groups=groups,subClass_indx=-1)
# Out:
# ========Execution Accuracy=============
#
#
# | Group | Easy | Medium | Hard | ExtraHard | All |
# |------|-------|-----|----------|----|
# | Distill R1-1.5B | 85.00 | 71.00 | 50.00 | 18.00 | 56.00 |
# | CodeLlama-13B | 84.00 | 70.00 | 43.00 | 19.00 | 54.00 |
# | CodeLlama-7B | 80.00 | 64.00 | 44.00 | 19.00 | 51.70 |
# | Stable Code-3B | 80.00 | 70.00 | 49.00 | 16.00 | 53.70 |
# | Deepseek Coder-1.3B | 81.00 | 65.00 | 46.00 | 18.00 | 52.50 |
# | TinyLlama-1.1B | 80.00 | 66.00 | 46.00 | 21.00 | 53.20 |
# ========Exact Matching Accuracy=============
#
#
# | Group | Easy | Medium | Hard | ExtraHard | All |
# |------|-------|-----|----------|----|
# | Distill R1-1.5B | 66.00 | 28.00 | 22.00 | 2.00 | 29.50 |
# | CodeLlama-13B | 72.00 | 29.00 | 28.00 | 3.00 | 33.00 |
# | CodeLlama-7B | 62.00 | 27.00 | 22.00 | 2.00 | 28.20 |
# | Stable Code-3B | 58.00 | 33.00 | 19.00 | 2.00 | 28.00 |
# | Deepseek Coder-1.3B | 63.00 | 28.00 | 23.00 | 3.00 | 29.20 |
# ...

# %% [markdown]
# ## Greedy

# %%
result_fnames ={
    "sc": "results\stable-code-3b_TinyLlama-1.1B-Chat-v1.0_spider_greedy_pro_e2e.txt",
    "dscoder": "results\deepseek-coder-1.3b-instruct_TinyLlama-1.1B-Chat-v1.0_base_spider_greedy_check_e2e_t2_20250220_164734.txt",
    "tl" : "results\TinyLlama-1.1B-Chat-v1.0_DeepSeek-R1-Distill-Qwen-1.5B_base_spider_greedy_pro_e2e.txt",
    "r1": "results\DeepSeek-R1-Distill-Qwen-1.5B_DeepSeek-R1-Distill-Qwen-1.5B_spider_greedy_pro_e2e.txt",
}

groups = [
    'Stable Code-3B',
    'DeepSeek Coder-1.3B', 
    'TinyLlama-1.1B',
    'Distill-R1-1.5B'
    ]

results = parse_results(result_fnames)
plot_accuracy(results=results, groups=groups)
plot_partial_matching(results=results,groups=groups)
plot_matching(results=results,groups=groups,subClass_indx=-1)
# Out:
# ========Execution Accuracy=============
#
#
# | Group | Easy | Medium | Hard | ExtraHard | All |
# |------|-------|-----|----------|----|
# | Stable Code-3B | 83.00 | 73.00 | 51.00 | 24.00 | 57.80 |
# | DeepSeek Coder-1.3B | 73.00 | 61.00 | 42.00 | 16.00 | 48.00 |
# | TinyLlama-1.1B | 33.00 | 8.00 | 4.00 | 0.00 | 11.30 |
# | Distill-R1-1.5B | 17.00 | 9.00 | 3.00 | 0.00 | 7.20 |
# ========Exact Matching Accuracy=============
#
#
# | Group | Easy | Medium | Hard | ExtraHard | All |
# |------|-------|-----|----------|----|
# | Stable Code-3B | 73.00 | 32.00 | 26.00 | 4.00 | 33.80 |
# | DeepSeek Coder-1.3B | 55.00 | 16.00 | 7.00 | 1.00 | 19.80 |
# | TinyLlama-1.1B | 25.00 | 5.00 | 0.00 | 0.00 | 7.50 |
# | Distill-R1-1.5B | 9.00 | 6.00 | 1.00 | 0.00 | 4.00 |
# ========Partial Matching Accuracy=============
#
#
# | Group | Easy | Medium | Hard | ExtraHard | All |
# |------|-------|-----|----------|----|
# | Stable Code-3B | 76.40 | 62.43 | 76.86 | 51.99 | 69.50 |
# ...

# %% [markdown]
# ## Ablation Study:
#
# ### Max token limit

# %%
from utils.log_parser import log_parser, fail_rate_calc, extraction_process, count_repeated_sentences, compute_ttr, compute_entropy, repeated_ngrams, compute_diversity
import numpy as np
from sentence_transformers import SentenceTransformer

logfiles = [
    "DeepSeek-R1-Distill-Qwen-1.5B_spider_NoExecResult_20250219_164330",
    "DeepSeek-R1-Distill-Qwen-1.5B_spider_NoExecResult_20250219_172321",
    "DeepSeek-R1-Distill-Qwen-1.5B_spider_NoExecResult_20250219_182037",
    "DeepSeek-R1-Distill-Qwen-1.5B_spider_NoExecResult_20250219_192746",
    "DeepSeek-R1-Distill-Qwen-1.5B_spider_NoExecResult_20250219_204553",
    "DeepSeek-R1-Distill-Qwen-1.5B_spider_NoExecResult_20250221_021459",
    "DeepSeek-R1-Distill-Qwen-1.5B_spider_NoExecResult_20250221_035920"

     # w/o schema new text prompt v2
#    "DeepSeek-R1-Distill-Qwen-1.5B_spider_NoExecResult_20250306_014223",
#    "DeepSeek-R1-Distill-Qwen-1.5B_spider_NoExecResult_20250306_022534",
#    "DeepSeek-R1-Distill-Qwen-1.5B_spider_NoExecResult_20250306_000330",
#    "DeepSeek-R1-Distill-Qwen-1.5B_spider_NoExecResult_20250306_032446",
#    "DeepSeek-R1-Distill-Qwen-1.5B_spider_NoExecResult_20250306_044918",
#    "DeepSeek-R1-Distill-Qwen-1.5B_spider_NoExecResult_20250306_062039",
#    "DeepSeek-R1-Distill-Qwen-1.5B_spider_NoExecResult_20250306_080547"    
]

sentence_model = SentenceTransformer("all-MiniLM-L6-v2")  # Small but effective model for Sentence Embeddings

eval_max_new_tokens_list = []
pws_acc_list = []
f1_list = []
hit1_list= []
mrr_list= []
fail_rate_list= []
avg_repetition_list = []
ttr_list = []
entropy_list = []
ngrams_list5 = []
ngrams_list10 = []
diversity_list = []

for i in range(len(logfiles)):
    fname = "log/"+ logfiles[i]+ ".json"

    result = log_parser(fname)
    eval_max_new_tokens = result["Parameters"]["evaluator_max_new_tokens"]
    pws_acc = result["Evaluation"]["PWS Acc"]
    f1 = result["Evaluation"]["Macro F1"]
    hit1 = result["Evaluation"]["Hit@1"]
    mrr = result["Evaluation"]["MRR"]
    fail_rate = fail_rate_calc(result)
    all_sentences, all_text = extraction_process(result)

    all_avg_repeated_sen = []
    for sentences in all_sentences:
        repeated_counts, repetition_ratio = count_repeated_sentences(sentences)
        # avg_rep = np.mean(list(repeated_counts.values()))
        avg_rep = repetition_ratio * 100
        all_avg_repeated_sen.append(avg_rep)
    avg_repetition = np.mean(np.array(all_avg_repeated_sen))
    avg_repetition_list.append(avg_repetition)

    all_ttr = []
    for sentences in all_sentences:
        all_ttr.append(1 - compute_ttr(sentences))
    all_ttr = np.mean(np.array(all_ttr))
    ttr_list.append(all_ttr * 100)

    all_entropy = []
    for sentences in all_sentences:
        all_entropy.append(compute_entropy(sentences))
    all_entropy = np.mean(np.array(all_entropy))
    entropy_list.append(all_entropy)

    all_rngrams = []
    for text in all_text:
        repeated_ngam, repetition_ratio_ngam = repeated_ngrams(text, n=3)
        all_rngrams.append(repetition_ratio_ngam)
    all_rngrams = np.mean(np.array(all_rngrams))
    ngrams_list5.append(all_rngrams * 100)

    all_rngrams = []
    for text in all_text:
        repeated_ngam, repetition_ratio_ngam = repeated_ngrams(text, n=2)
        all_rngrams.append(repetition_ratio_ngam)
    all_rngrams = np.mean(np.array(all_rngrams))
    ngrams_list10.append(all_rngrams * 100)

    all_divs = []
    for sentences in all_sentences:
        all_divs.append(compute_diversity(sentences, sentence_model))
    all_divs = np.mean(np.array(all_divs))
    diversity_list.append(all_divs * 100)

    eval_max_new_tokens_list.append(eval_max_new_tokens)
    pws_acc_list.append(pws_acc * 100)
    f1_list.append(f1 * 100)
    hit1_list.append(hit1 * 100)
    mrr_list.append(mrr * 100)
    fail_rate_list.append(fail_rate)
# Out:
# c:\Users\fahim\anaconda3\envs\r1\lib\site-packages\transformers\models\bert\modeling_bert.py:440: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:263.)
#   attn_output = torch.nn.functional.scaled_dot_product_attention(

# %%
# Create subplots
import matplotlib.pyplot as plt
from utils.log_parser import generate_markdown_table

x = eval_max_new_tokens_list
y_values = [pws_acc_list, f1_list, hit1_list, mrr_list, fail_rate_list, avg_repetition_list, ttr_list, ngrams_list10, entropy_list, diversity_list]
titles = ['Accuracy','Macro F1','Hit@1','MRR','Fail Rate', 'Repetition Ratio','1 - TTR', 'Repeated n-grams', 'Entropy', 'Diversity']

rows = 2
cols = 5
# Create subplots
fig, axes = plt.subplots(rows, cols, figsize=(12, 6), sharex=True)

# Get distinct colors from the 'tab10' colormap
colors = plt.cm.tab10(np.arange(len(y_values)))

# Flatten axes in case of single row/column
axes = axes.flatten()

for i in range(len(y_values)):
    axes[i].plot(x, y_values[i], marker='o', linestyle='-', color=colors[i])
    axes[i].set_title(titles[i])
    #axes[i].set_ylabel(f"y{i+1}")

# Hide any empty subplots
for j in range(len(y_values), len(axes)):
    fig.delaxes(axes[j])

axes[-1].set_xlabel("Max new token")  # Set xlabel on the last subplot


for ax in axes:
        ax.spines['top'].set_visible(False)
        ax.spines['right'].set_visible(False)
        #ax.spines['left'].set_visible(False)
        #ax.spines['bottom'].set_visible(False)

plt.tight_layout()
plt.show()

markdown_table = generate_markdown_table(x, y_values, titles, xtitle="max_new_tokens")
print(markdown_table)
# Out:
# | max_new_tokens | Accuracy | Macro F1 | Hit@1 | MRR | Fail Rate | Repetition Ratio | 1 - TTR | Repeated n-grams | Entropy | Diversity |
# |----------------|----------|----------|-------|-----|-----------|------------------|---------|------------------|---------|-----------|
# | 256 | 1.96 | 42.87 | 53.75 | 60.98 | 94.30 | 0.15 | 0.09 | 28.62 | 3.79 | 64.54 |
# | 400 | 32.03 | 61.89 | 55.00 | 62.07 | 50.77 | 0.74 | 0.40 | 38.42 | 4.31 | 64.48 |
# | 512 | 51.34 | 58.70 | 56.50 | 62.83 | 23.57 | 1.23 | 0.69 | 41.20 | 4.45 | 64.64 |
# | 700 | 55.26 | 55.75 | 55.75 | 62.49 | 8.86 | 2.31 | 1.40 | 42.72 | 4.50 | 64.70 |
# | 1024 | 56.23 | 55.20 | 55.75 | 62.45 | 6.10 | 3.67 | 2.52 | 43.40 | 4.49 | 64.58 |
# | 1536 | 55.99 | 55.28 | 55.50 | 62.32 | 5.92 | 4.60 | 3.57 | 43.78 | 4.47 | 64.42 |
# | 2048 | 55.99 | 55.28 | 55.50 | 62.32 | 5.92 | 5.03 | 4.12 | 43.94 | 4.46 | 64.32 |

# %% [markdown]
# ### effect of adding schema
#
# 1. Naive mode

# %%
from utils.log_parser import log_parser, fail_rate_calc, extraction_process, count_repeated_sentences, compute_ttr, compute_entropy, repeated_ngrams, compute_diversity
import numpy as np
from sentence_transformers import SentenceTransformer
from utils.log_parser import generate_markdown_table

logfiles = [
    "DeepSeek-R1-Distill-Qwen-1.5B_spider_NoExecResult_20250219_204553", # no schema
    "DeepSeek-R1-Distill-Qwen-1.5B_spider_NoExecResult_20250220_220800", # schema used
]

sentence_model = SentenceTransformer("all-MiniLM-L6-v2")  # Small but effective model for Sentence Embeddings

eval_max_new_tokens_list = []
pws_acc_list = []
f1_list = []
hit1_list= []
mrr_list= []
fail_rate_list= []
avg_repetition_list = []
ttr_list = []
entropy_list = []
ngrams_list5 = []
ngrams_list10 = []
diversity_list = []

for i in range(len(logfiles)):
    fname = "log/"+ logfiles[i]+ ".json"

    result = log_parser(fname)
    eval_max_new_tokens = result["Parameters"]["evaluator_max_new_tokens"]
    pws_acc = result["Evaluation"]["PWS Acc"]
    f1 = result["Evaluation"]["Macro F1"]
    hit1 = result["Evaluation"]["Hit@1"]
    mrr = result["Evaluation"]["MRR"]
    fail_rate = fail_rate_calc(result)
    all_sentences, all_text = extraction_process(result)

    all_avg_repeated_sen = []
    for sentences in all_sentences:
        repeated_counts, repetition_ratio = count_repeated_sentences(sentences)
        # avg_rep = np.mean(list(repeated_counts.values()))
        avg_rep = repetition_ratio * 100
        all_avg_repeated_sen.append(avg_rep)
    avg_repetition = np.mean(np.array(all_avg_repeated_sen))
    avg_repetition_list.append(avg_repetition)

    all_ttr = []
    for sentences in all_sentences:
        all_ttr.append(1 - compute_ttr(sentences))
    all_ttr = np.mean(np.array(all_ttr))
    ttr_list.append(all_ttr * 100)

    all_entropy = []
    for sentences in all_sentences:
        all_entropy.append(compute_entropy(sentences))
    all_entropy = np.mean(np.array(all_entropy))
    entropy_list.append(all_entropy)

    all_rngrams = []
    for text in all_text:
        repeated_ngam, repetition_ratio_ngam = repeated_ngrams(text, n=3)
        all_rngrams.append(repetition_ratio_ngam)
    all_rngrams = np.mean(np.array(all_rngrams))
    ngrams_list5.append(all_rngrams * 100)

    all_rngrams = []
    for text in all_text:
        repeated_ngam, repetition_ratio_ngam = repeated_ngrams(text, n=2)
        all_rngrams.append(repetition_ratio_ngam)
    all_rngrams = np.mean(np.array(all_rngrams))
    ngrams_list10.append(all_rngrams * 100)

    all_divs = []
    for sentences in all_sentences:
        all_divs.append(compute_diversity(sentences, sentence_model))
    all_divs = np.mean(np.array(all_divs))
    diversity_list.append(all_divs * 100)

    eval_max_new_tokens_list.append(eval_max_new_tokens)
    pws_acc_list.append(pws_acc * 100)
    f1_list.append(f1 * 100)
    hit1_list.append(hit1 * 100)
    mrr_list.append(mrr * 100)
    fail_rate_list.append(fail_rate)



print(f"Max tokens: {eval_max_new_tokens_list}")
x = ['w/o Schema', 'with Schema']
y_values = [pws_acc_list, f1_list, hit1_list, mrr_list, fail_rate_list, avg_repetition_list, ttr_list, ngrams_list10, entropy_list, diversity_list]
titles = ['Accuracy','Macro F1','Hit@1','MRR','Fail Rate', 'Repetition Ratio','1 - TTR', 'Repeated n-grams', 'Entropy', 'Diversity']

print(generate_markdown_table(x,y_values,titles,'Prompt Condition'))
# Out:
# Max tokens: [1024, 1024]
# | Prompt Condition | Accuracy | Macro F1 | Hit@1 | MRR | Fail Rate | Repetition Ratio | 1 - TTR | Repeated n-grams | Entropy | Diversity |
# |------------------|----------|----------|-------|-----|-----------|------------------|---------|------------------|---------|-----------|
# | w/o Schema | 56.23 | 55.20 | 55.75 | 62.45 | 6.10 | 3.67 | 2.52 | 43.40 | 4.49 | 64.58 |
# | with Schema | 53.79 | 53.90 | 56.25 | 62.56 | 19.24 | 7.07 | 4.94 | 48.73 | 4.68 | 64.14 |

# %% [markdown]
# ### Soft vs Hard

# %%
from utils.log_parser import log_parser, fail_rate_calc, extraction_process, count_repeated_sentences, compute_ttr, compute_entropy, repeated_ngrams, compute_diversity
import numpy as np
from sentence_transformers import SentenceTransformer

logfiles = [
    "DeepSeek-R1-Distill-Qwen-1.5B_spider_NoExecResult_20250217_195656", # soft, naive
    "DeepSeek-R1-Distill-Qwen-1.5B_spider_NoExecResult_20250213_145336", # hard, naive
    "DeepSeek-R1-Distill-Qwen-1.5B_spider_NoExecResult_20250217_233452", # soft, check
    "DeepSeek-R1-Distill-Qwen-1.5B_spider_NoExecResult_20250216_131655", # hard, check  
]

sentence_model = SentenceTransformer("all-MiniLM-L6-v2")  # Small but effective model for Sentence Embeddings

eval_max_new_tokens_list = []
pws_acc_list = []
f1_list = []
hit1_list= []
mrr_list= []
fail_rate_list= []
avg_repetition_list = []
ttr_list = []
entropy_list = []
ngrams_list5 = []
ngrams_list10 = []
diversity_list = []

for i in range(len(logfiles)):
    fname = "log/"+ logfiles[i]+ ".json"

    result = log_parser(fname)
    #eval_max_new_tokens = result["Parameters"]["evaluator_max_new_tokens"]
    pws_acc = result["Evaluation"]["PWS Acc"]
    f1 = result["Evaluation"]["Macro F1"]
    hit1 = result["Evaluation"]["Hit@1"]
    mrr = result["Evaluation"]["MRR"]
    fail_rate = 0 #fail_rate_calc(result)
    all_sentences, all_text = extraction_process(result)

    all_avg_repeated_sen = []
    for sentences in all_sentences:
        repeated_counts, repetition_ratio = count_repeated_sentences(sentences)
        # avg_rep = np.mean(list(repeated_counts.values()))
        avg_rep = repetition_ratio * 100
        all_avg_repeated_sen.append(avg_rep)
    avg_repetition = np.mean(np.array(all_avg_repeated_sen))
    avg_repetition_list.append(avg_repetition)

    all_ttr = []
    for sentences in all_sentences:
        all_ttr.append(1 - compute_ttr(sentences))
    all_ttr = np.mean(np.array(all_ttr))
    ttr_list.append(all_ttr * 100)

    all_entropy = []
    for sentences in all_sentences:
        all_entropy.append(compute_entropy(sentences))
    all_entropy = np.mean(np.array(all_entropy))
    entropy_list.append(all_entropy)

    all_rngrams = []
    for text in all_text:
        repeated_ngam, repetition_ratio_ngam = repeated_ngrams(text, n=3)
        all_rngrams.append(repetition_ratio_ngam)
    all_rngrams = np.mean(np.array(all_rngrams))
    ngrams_list5.append(all_rngrams * 100)

    all_rngrams = []
    for text in all_text:
        repeated_ngam, repetition_ratio_ngam = repeated_ngrams(text, n=2)
        all_rngrams.append(repetition_ratio_ngam)
    all_rngrams = np.mean(np.array(all_rngrams))
    ngrams_list10.append(all_rngrams * 100)

    all_divs = []
    for sentences in all_sentences:
        all_divs.append(compute_diversity(sentences, sentence_model))
    all_divs = np.mean(np.array(all_divs))
    diversity_list.append(all_divs * 100)

    #eval_max_new_tokens_list.append(eval_max_new_tokens)
    pws_acc_list.append(pws_acc * 100)
    f1_list.append(f1 * 100)
    hit1_list.append(hit1 * 100)
    mrr_list.append(mrr * 100)
    fail_rate_list.append(fail_rate)

# %%
print(f"Max tokens: {eval_max_new_tokens_list}")
x = ['soft: Naive Discriminator', 'hard: Naive Discriminator', 'soft: + Executability Check', 'hard: + Executability Check']
y_values = [pws_acc_list, f1_list, hit1_list, mrr_list, fail_rate_list, avg_repetition_list, ttr_list, ngrams_list10, entropy_list, diversity_list]
titles = ['Accuracy','Macro F1','Hit@1','MRR','Fail Rate', 'Repetition Ratio','1 - TTR', 'Repeated n-grams', 'Entropy', 'Diversity']

print(generate_markdown_table(x,y_values,titles,'Prompt Condition'))


y_values = [pws_acc_list, f1_list, hit1_list, mrr_list]
titles = ['Accuracy','Macro F1','Hit@1','MRR']

print(generate_markdown_table(x,y_values,titles,'Prompt Condition'))
# Out:
# Max tokens: []
# | Prompt Condition | Accuracy | Macro F1 | Hit@1 | MRR | Fail Rate | Repetition Ratio | 1 - TTR | Repeated n-grams | Entropy | Diversity |
# |------------------|----------|----------|-------|-----|-----------|------------------|---------|------------------|---------|-----------|
# | soft: Naive Discriminator | 51.34 | 58.70 | 56.50 | 62.83 | 0.00 | 1.23 | 0.69 | 41.20 | 4.45 | 64.64 |
# | hard: Naive Discriminator | 34.47 | 58.96 | 57.50 | 63.10 | 0.00 | 1.23 | 0.69 | 41.20 | 4.45 | 64.64 |
# | soft: + Executability Check | 78.48 | 69.29 | 63.25 | 67.09 | 0.00 | 1.38 | 3.12 | 40.60 | 4.32 | 65.29 |
# | hard: + Executability Check | 69.44 | 69.48 | 63.75 | 67.16 | 0.00 | 1.38 | 3.12 | 40.60 | 4.32 | 65.29 |
#
# | Prompt Condition | Accuracy | Macro F1 | Hit@1 | MRR |
# |------------------|----------|----------|-------|-----|
# | soft: Naive Discriminator | 51.34 | 58.70 | 56.50 | 62.83 |
# | hard: Naive Discriminator | 34.47 | 58.96 | 57.50 | 63.10 |
# ...

# %% [markdown]
# e2e results for hard vs soft
#
# 1. naive mode

# %%
from utils.results import parse_results, plot_accuracy, plot_partial_matching, plot_matching

result_fnames ={
    "soft": "results/stable-code-3b_DeepSeek-R1-Distill-Qwen-1.5B_reason_spider_rerank_base_e2e_t2_20250218_092532.txt",
    'hard': "results/stable-code-3b_DeepSeek-R1-Distill-Qwen-1.5B_reason_spider_rerank_base_e2e_t2_20250216_085324.txt",
}

groups = ['with logits',
          'w/o logits'
          ]

results = parse_results(result_fnames)
plot_accuracy(results=results, groups=groups)
plot_partial_matching(results=results,groups=groups)
plot_matching(results=results,groups=groups,subClass_indx=-1)
# Out:
# ========Execution Accuracy=============
#
#
# | Group | Easy | Medium | Hard | ExtraHard | All |
# |------|-------|-----|----------|----|
# | with logits | 85.00 | 71.00 | 50.00 | 18.00 | 56.00 |
# | w/o logits | 86.00 | 67.00 | 50.00 | 18.00 | 55.20 |
# ========Exact Matching Accuracy=============
#
#
# | Group | Easy | Medium | Hard | ExtraHard | All |
# |------|-------|-----|----------|----|
# | with logits | 66.00 | 28.00 | 22.00 | 2.00 | 29.50 |
# | w/o logits | 67.00 | 32.00 | 21.00 | 1.00 | 30.20 |
# ========Partial Matching Accuracy=============
#
#
# | Group | Easy | Medium | Hard | ExtraHard | All |
# |------|-------|-----|----------|----|
# | with logits | 75.37 | 60.06 | 68.31 | 52.58 | 65.51 |
# | w/o logits | 77.10 | 62.67 | 68.01 | 52.42 | 67.16 |
# ========Partial Matching Recall=============
#
#
# | Group | Easy | Medium | Hard | ExtraHard | All |
# |------|-------|-----|----------|----|
# | with logits | 70.98 | 41.91 | 45.04 | 28.54 | 43.06 |
# ...

# %% [markdown]
# 2. check mode

# %%
from utils.results import parse_results, plot_accuracy, plot_partial_matching, plot_matching

result_fnames ={
    "soft": "results/stable-code-3b_DeepSeek-R1-Distill-Qwen-1.5B_reason_spider_rerank_check_e2e_t2_20250218_011727.txt",
    'hard': "results/stable-code-3b_DeepSeek-R1-Distill-Qwen-1.5B_reason_spider_rerank_check_e2e_t2_20250216_165848.txt",
}

groups = ['with logits',
          'w/o logits'
          ]

results = parse_results(result_fnames)
plot_accuracy(results=results, groups=groups)
plot_partial_matching(results=results,groups=groups)
plot_matching(results=results,groups=groups,subClass_indx=-1)
# Out:
# ========Execution Accuracy=============
#
#
# | Group | Easy | Medium | Hard | ExtraHard | All |
# |------|-------|-----|----------|----|
# | with logits | 85.00 | 70.00 | 52.00 | 26.00 | 58.30 |
# | w/o logits | 86.00 | 70.00 | 51.00 | 25.00 | 58.00 |
# ========Exact Matching Accuracy=============
#
#
# | Group | Easy | Medium | Hard | ExtraHard | All |
# |------|-------|-----|----------|----|
# | with logits | 67.00 | 31.00 | 21.00 | 2.00 | 30.20 |
# | w/o logits | 68.00 | 36.00 | 22.00 | 1.00 | 31.80 |
# ========Partial Matching Accuracy=============
#
#
# | Group | Easy | Medium | Hard | ExtraHard | All |
# |------|-------|-----|----------|----|
# | with logits | 75.37 | 62.44 | 66.00 | 50.88 | 63.73 |
# | w/o logits | 77.10 | 64.15 | 66.39 | 49.94 | 64.83 |
# ========Partial Matching Recall=============
#
#
# | Group | Easy | Medium | Hard | ExtraHard | All |
# |------|-------|-----|----------|----|
# | with logits | 70.98 | 44.58 | 46.62 | 32.48 | 45.45 |
# ...
